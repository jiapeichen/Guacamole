# %%
import matplotlib.pyplot as plt 
fig = plt.figure()
plt.plot([1,2,3,4,5],[0,1,0,1,0])

from IPython.core.display import display
display(fig)

# %%
# %pwd
# Out:
# '/Users/jiapei/Desktop'

# %%
0x52
# Out:
# 82

# %%
# %ls
# Out:
# 00001-Maryam-Nassir-Zadeh_Resort21.jpg
# 00007-Maryam-Nassir-Zadeh_Resort21.jpg
# 00020-ROKH-RESORT-21.jpg
# 05-tokyo-ss-fw19-kira-day-6.jpg
# 10.1126@science.aba5906.pdf
# 12-seoul-street-style-fw19-alex-finch-day-3.jpg
# 15GW data.xlsx
# 36-tokyo-fashion-week-fall-2019-street-style.jpg
# 3D printing/
# ABI_prenatal_FindModules/
# AI in medical imaging.pdf
# ATAC-seq Protocol - Kaestner Lab (for website).docx
# Arid1A project/
# DESeq2/
# DanceTroupe/
# DiveIntoPython.pdf
# Figure 2-Transcriptomes-v1.jpg
# Figures/
# GradFundingOpps5620.xlsx
# HUVEC cell culture/
# Machine-Learning-in-R-master/
# ProofIncomeJiapeiChen2020.pdf
# R/
# Rental application 1621Irving2020.pdf
# SWITCH NP/
# Screen Shot 2020-05-13 at 4.16.22 PM (2).png
# Screen Shot 2020-06-29 at 12.36.10 AM.png
# Screen Shot 2020-07-28 at 7.45.21 PM.png
# UCSF BMS/
# Untitled.ipynb
# VEGFA vasculogenesis.pdf
# bulk RNAseq/
# chromatin accessibility dev brain.pdf
# consolidated readings.docx
# deep learning/
# ...

# %%
# %cd /Python
# Out:
# [Errno 2] No such file or directory: '/Python'
# /Users/jiapei/Desktop

# %%
# %cd /Users/jiapei/Desktop/Python
# Out:
# /Users/jiapei/Desktop/python

# %%
# %ls
# Out:
# get-pip.py*                         thinkpython.pdf
# practical bioinformatics in python/

# %%
# %pwd
# Out:
# '/Users/jiapei/Desktop/python'
